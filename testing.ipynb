# %%
from src.api import DadosAbertosPBAPI
from src.extractor import BaseExtractor
from typing import Any, Dict, List

api = DadosAbertosPBAPI()
ano_target = 2025

# %%
class AtasExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "atas"

    @property
    def period_mode(self) -> str:
        return "ano_inicio_vigencia"

    def fetch_vigencia_records(self, year: int) -> List[Dict[str, Any]]:
        return self.api.obter_todas_atas_registro_preco(ano_inicio_vigencia=year)

extrator = AtasExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(2026, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 19:04:46,808 - src.extractor - INFO -
# ...
# 2026-09-18 19:04:46,811 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 19:04:46,812 - src.extractor - INFO - ============================================================
# 2026-09-18 19:04:47,447 - src.extractor - INFO - Total para 2026: 1943 registros
# 2026-09-18 19:04:47,475 - src.extractor - INFO - CSV salvo: dados/atas_2026.csv
# 2026-09-18 19:04:47,512 - src.extractor - INFO - Relatório salvo: dados/atas_2026_relatorio.txt
# Total: 1943
# {'csv': PosixPath('dados/atas_2026.csv')}

# %%
class NotasEmpenhoExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "notas_empenho"

    def fetch_month_records(self, year: int, month: int) -> List[Dict[str, Any]]:
        return self.api.obter_todas_notas_empenho(ano=year, mes=month)

extrator = NotasEmpenhoExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(2026, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 21:08:44,740 - src.extractor - INFO -
# ...
# 2026-09-18 21:08:44,743 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 21:08:44,743 - src.extractor - INFO - ============================================================
# 2026-09-18 21:08:44,889 - src.api - INFO - Página 1/75 - Total acumulado: 100 registros
# 2026-09-18 21:08:44,946 - src.api - INFO - Página 2/75 - Total acumulado: 200 registros
# 2026-09-18 21:08:44,999 - src.api - INFO - Página 3/75 - Total acumulado: 300 registros
# 2026-09-18 21:08:45,045 - src.api - INFO - Página 4/75 - Total acumulado: 400 registros
# 2026-09-18 21:08:45,087 - src.api - INFO - Página 5/75 - Total acumulado: 500 registros
# 2026-09-18 21:08:45,128 - src.api - INFO - Página 6/75 - Total acumulado: 600 registros
# 2026-09-18 21:08:45,169 - src.api - INFO - Página 7/75 - Total acumulado: 700 registros
# 2026-09-18 21:08:45,210 - src.api - INFO - Página 8/75 - Total acumulado: 800 registros
# ...

# %%
class LiquidacoesExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "liquidacoes"

    def fetch_month_records(self, year: int, month: int) -> List[Dict[str, Any]]:
        return self.api.obter_todas_liquidacoes(ano=year, mes=month)
ano_target = 2025
extrator = LiquidacoesExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(ano_target, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 21:00:55,532 - src.extractor - INFO -
# ...
# 2026-09-18 21:00:55,535 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 21:00:55,537 - src.extractor - INFO - ============================================================
# 2026-09-18 21:00:55,970 - src.api - INFO - Página 1/56 - Total acumulado: 100 registros
# 2026-09-18 21:00:56,022 - src.api - INFO - Página 2/56 - Total acumulado: 200 registros
# 2026-09-18 21:00:56,056 - src.api - INFO - Página 3/56 - Total acumulado: 300 registros
# 2026-09-18 21:00:56,092 - src.api - INFO - Página 4/56 - Total acumulado: 400 registros
# 2026-09-18 21:00:56,132 - src.api - INFO - Página 5/56 - Total acumulado: 500 registros
# 2026-09-18 21:00:56,171 - src.api - INFO - Página 6/56 - Total acumulado: 600 registros
# 2026-09-18 21:00:56,220 - src.api - INFO - Página 7/56 - Total acumulado: 700 registros
# 2026-09-18 21:00:56,254 - src.api - INFO - Página 8/56 - Total acumulado: 800 registros
# ...

# %%
from src.api import DadosAbertosPBAPI
from src.extractor import BaseExtractor
from typing import Any, Dict, List

api = DadosAbertosPBAPI()

class ContratosExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "contratos"

    def fetch_year_records(self, year: int) -> List[Dict[str, Any]]:
        return self.api.obter_todos_contratos(ano_inicio_vigencia=year)

ano_target = 2026
extrator = ContratosExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(ano_target, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 21:16:50,842 - src.extractor - INFO -
# ...
# 2026-09-18 21:16:50,843 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 21:16:50,844 - src.extractor - INFO - ============================================================
# 2026-09-18 21:16:53,616 - src.extractor - INFO - Total para 2026: 4807 registros
# 2026-09-18 21:16:53,783 - src.extractor - INFO - CSV salvo: dados/contratos_2026.csv
# 2026-09-18 21:16:53,872 - src.extractor - INFO - Relatório salvo: dados/contratos_2026_relatorio.txt
# Total: 4807
# {'csv': PosixPath('dados/contratos_2026.csv')}

# %%
class ContratacoesExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "contratacoes"

    def fetch_month_records(self, year: int, month: int) -> List[Dict[str, Any]]:
        return self.api.obter_todas_contratacoes(ano=year, mes=month)
ano_target = 2026
extrator = ContratacoesExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(ano_target, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 21:19:29,857 - src.extractor - INFO -
# ...
# 2026-09-18 21:19:29,858 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 21:19:29,859 - src.extractor - INFO - ============================================================
# 2026-09-18 21:19:29,893 - src.api - INFO - Página 1/20 - Total acumulado: 100 registros
# 2026-09-18 21:19:29,947 - src.api - INFO - Página 2/20 - Total acumulado: 200 registros
# 2026-09-18 21:19:29,998 - src.api - INFO - Página 3/20 - Total acumulado: 300 registros
# 2026-09-18 21:19:30,054 - src.api - INFO - Página 4/20 - Total acumulado: 400 registros
# 2026-09-18 21:19:30,106 - src.api - INFO - Página 5/20 - Total acumulado: 500 registros
# 2026-09-18 21:19:30,154 - src.api - INFO - Página 6/20 - Total acumulado: 600 registros
# 2026-09-18 21:19:30,213 - src.api - INFO - Página 7/20 - Total acumulado: 700 registros
# 2026-09-18 21:19:30,264 - src.api - INFO - Página 8/20 - Total acumulado: 800 registros
# ...

# %%
class ServidoresExtractor(BaseExtractor):
    @property
    def resource_name(self) -> str:
        return "servidores"

    def fetch_month_records(self, year: int, month: int) -> List[Dict[str, Any]]:
        return self.api.obter_todos_servidores(ano=year, mes=month)

extrator = ServidoresExtractor(api=api, output_dir="./dados")
resultado = extrator.extract_and_save_year(ano_target, formats=["csv"], include_report=True)
print(f"Total: {resultado['total_registros']}")
print(resultado["arquivos"])
# Out:
# 2026-09-18 21:25:21,714 - src.extractor - INFO -
# ...
# 2026-09-18 21:25:21,715 - src.extractor - INFO - Processando ano 2026
# 2026-09-18 21:25:21,716 - src.extractor - INFO - ============================================================
# 2026-09-18 21:25:22,120 - src.api - INFO - Página 1/1335 - Total acumulado: 100 registros
# 2026-09-18 21:25:22,369 - src.api - INFO - Página 2/1335 - Total acumulado: 200 registros
# 2026-09-18 21:25:22,623 - src.api - INFO - Página 3/1335 - Total acumulado: 300 registros
# 2026-09-18 21:25:22,860 - src.api - INFO - Página 4/1335 - Total acumulado: 400 registros
# 2026-09-18 21:25:23,105 - src.api - INFO - Página 5/1335 - Total acumulado: 500 registros
# 2026-09-18 21:25:23,345 - src.api - INFO - Página 6/1335 - Total acumulado: 600 registros
# 2026-09-18 21:25:23,581 - src.api - INFO - Página 7/1335 - Total acumulado: 700 registros
# 2026-09-18 21:25:23,819 - src.api - INFO - Página 8/1335 - Total acumulado: 800 registros
# ...
